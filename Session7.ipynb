# %% [markdown]
# # Sets

# %% [markdown]
# ### Create a set

# %%
my_set = {1,2,3,4,5,2,3,4,5,7}

# %% [markdown]
# ### No duplicate values in sets

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 7}

# %% [markdown]
# ### unindexed

# %%
my_set[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-158c424478a1> in <module>
# ----> 1 my_set[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## Mutable Sets

# %% [markdown]
# ### Adding

# %%
set2 = {'a', 'b' , 'd', 'e', 'f'}
set2
# Out:
# {'a', 'b', 'd', 'e', 'f'}

# %%
set2.add('c')
set2
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %% [markdown]
# ### Removing

# %%
set2.remove('b')

# %%
set2
# Out:
# {'a', 'd', 'e', 'f'}

# %% [markdown]
# ## unordered

# %%
letters = 'abcdefghi'

print('String: ', str(letters))
print('List: ', list(letters))
print('Set: ', set(letters))
# Out:
# String:  abcdefghi
# List:  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']
# Set:  {'e', 'a', 'f', 'i', 'h', 'g', 'b', 'd', 'c'}

# %% [markdown]
# ![sets-2.jpg](attachment:sets-2.jpg)

# %%
A = {1,2,3,4,5}
B = {2,3}

# %% [markdown]
# ### Difference

# %%
A - B
# Out:
# {1, 4, 5}

# %%
A.difference(B) #A - B
# Out:
# {1, 4, 5}

# %% [markdown]
# ### Union

# %%
A + B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-151064de832d> in <module>
# ----> 1 A + B
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
A.union(B)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Intersection

# %%
A.intersection(B)
# Out:
# {2, 3}

# %%
A & B
# Out:
# {2, 3}

# %% [markdown]
# ![set_operations.jpg](attachment:set_operations.jpg)

# %% [markdown]
# ## Example

# %%
A = {'A', 'B', 'C', 'D', 'E', 'F'}
B = {'D', 'E', 'F', 'G', 'H', 'I'}

# %% [markdown]
# ### Intersection

# %%
A & B
# Out:
# {'D', 'E', 'F'}

# %%
A.intersection(B)
# Out:
# {'D', 'E', 'F'}

# %% [markdown]
# ### difference

# %%
A - B
# Out:
# {'A', 'B', 'C'}

# %%
A.difference(B)
# Out:
# {'A', 'B', 'C'}

# %% [markdown]
# ### symmetric difference

# %%
A ^ B
# Out:
# {'A', 'B', 'C', 'G', 'H', 'I'}

# %%
#A.union(B)
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'}

# %%
A.union(B) - A.intersection(B)
# Out:
# {'A', 'B', 'C', 'G', 'H', 'I'}

# %% [markdown]
# ### Practice

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

#output: 40, 50, 30 ?

# %%
set1.intersection(set2)
# Out:
# {30, 40, 50}

# %%
set('ABCCCCCCDDDEFG')
# Out:
# {'A', 'B', 'C', 'D', 'E', 'F', 'G'}

# %%
list('ABCCCCCCDDDEFG')
# Out:
# ['A', 'B', 'C', 'C', 'C', 'C', 'C', 'C', 'D', 'D', 'D', 'E', 'F', 'G']

# %% [markdown]
# Good Luck ;)
